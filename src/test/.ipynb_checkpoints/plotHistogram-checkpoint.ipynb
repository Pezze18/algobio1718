# %%
import numpy as np
import matplotlib.pyplot as plt
# to get in-line plots
# %matplotlib nbagg

# %%
hist=[[1, 1425],
 [   2, 1348],
 [   3,  965],
 [   4,  756],
 [   5,  434],
 [   6,  272],
 [   7,  200],
 [   8,  118],
 [   9,   85],
 [  10,   50],
 [  11,   49],
 [  12,   24],
 [  13,   14],
 [  14,   11],
 [  15,    9],
 [  16,    2],
 [  17,    3],
 [  18,    7],
 [  19,    2],
 [  21,    2],
 [  23,    1],
 [  34,    2],
 [  46,    1],
 [  57,    1],
 [  67 ,   1]]

# %%
x=[e[0] for e in hist]
heights=[e[1] for e in hist]
plt.bar(x, heights, color="blue")
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'Histogram')
